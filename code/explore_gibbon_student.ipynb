# %% [markdown]
# # Exploring Gibbon

# %%
# imports
import os
import json
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import spacy

# %%
! pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\enhwi\miniconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (0.3.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (2.29.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: jinja2 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (67.8.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy) (1.26.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\enhwi\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\enhwi\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\enhwi\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\enhwi\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\enhwi\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\enhwi\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\enhwi\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\enhwi\miniconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\enhwi\miniconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: colorama in c:\users\enhwi\miniconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\enhwi\miniconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\enhwi\miniconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\enhwi\miniconda3\lib\site-packages (from jinja2->spacy) (2.1.1)

# %% [markdown]
# ## Pre-process text for analysis using SpaCy
#
# Before doing NLP work, most texts will need to be preprocessed in different ways. You may need to **tokenize** the text, remove stopwords, or **lemmatize** the text. What you do in pre-processing depends entirely on what your project is.

# %%
! python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.0/en_core_web_sm-3.7.0-py3-none-any.whl (12.8 MB)
#                                               0.0/12.8 MB ? eta -:--:--
#                                               0.0/12.8 MB ? eta -:--:--
#                                              0.1/12.8 MB 656.4 kB/s eta 0:00:20
#      --                                       0.8/12.8 MB 5.5 MB/s eta 0:00:03
#      -------                                  2.5/12.8 MB 14.6 MB/s eta 0:00:01
#      --------------                           4.6/12.8 MB 19.7 MB/s eta 0:00:01
#      ---------------------                    6.8/12.8 MB 24.0 MB/s eta 0:00:01
#      ---------------------------              8.8/12.8 MB 28.3 MB/s eta 0:00:01
#      ---------------------------------       11.2/12.8 MB 43.5 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 46.9 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 38.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\enhwi\miniconda3\lib\site-packages (from en-core-web-sm==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.3.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.29.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.4.2)
# Requirement already satisfied: jinja2 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (67.8.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\enhwi\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (1.26.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\enhwi\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\enhwi\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\enhwi\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\enhwi\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\enhwi\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\enhwi\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\enhwi\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\enhwi\miniconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\enhwi\miniconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.1.3)
# Requirement already satisfied: colorama in c:\users\enhwi\miniconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\enhwi\miniconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\enhwi\miniconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\enhwi\miniconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm", disable = ['ner', 'parser'])
nlp.max_length = 3045039

# %% [markdown]
# ### Open a file

# %%
# open a file
with open('../text/gibbon_sample.txt', encoding='utf8', mode='r') as f:
    sample = f.read()

# %%
sample

# %%
# create a spaCy doc
doc = nlp(sample)

# %%
# preview spaCy doc
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.is_stop, token.is_alpha)

# %% [markdown]
# ### List comprehension

# %%
# regular for loop to create a list

# %%
# list comprehension to create a list

# %% [markdown]
# ### Pre-process Gibbon
#
# For our immediate purposes we want to convert the raw text of Gibbon (which is in the form of `strings`) to a list of **lemmas**.

# %%
def get_noun_and_verb_lemmas(text):
    """Return a list of noun and verb lemmas from a string"""
    doc = nlp(text)
    tokens = [token for token in doc]
    noun_and_verb_tokens = [token for token in tokens if token.pos_ == 'NOUN' or token.pos_ == 'VERB']
    noun_and_verb_lemmas = [noun_and_verb_token.lemma_ for noun_and_verb_token in noun_and_verb_tokens]
    return noun_and_verb_lemmas

# %%
# Due to memory issues with spaCy it was necessary for me to find the longest file so that I could adjust some of SpaCy's
# default settings.
# You do not neet to run this code.
text_path = "../text/gibbon_decline_and_fall/" # path to unzipped gibbon_decline_and_fall directory
longest = 0
for file_name in os.listdir(text_path):
    with open(text_path + file_name, encoding='utf-8', mode='r') as f:
        raw_text = f.read()
    text_len = len(raw_text)
    if text_len > longest:
        longest = text_len
print(longest)

# %%
# Takes about 3 mintues
text_path = "../text/gibbon_decline_and_fall/"  # path to unzipped gibbon_decline_and_fall directory
gibbon_lemmas = {}
for file_name in os.listdir(text_path):
    chapter_name = file_name[23:29]
    with open(text_path + file_name, encoding='utf-8', mode = 'r') as f:
        raw_text = f.read()
    lemmas = get_noun_and_verb_lemmas(raw_text)
    gibbon_lemmas[chapter_name] = lemmas

# %%
# Attempt 2: This block of code is an alternative way to handle the memory limitations for spaCy.
# You do not need to run this code.
text_path = "../text/gibbon_decline_and_fall/"
gibbon_lemmas = {}
for file_name in os.listdir(text_path):
    chapter_name = file_name[23:29]
    with open(text_path + file_name, encoding='utf-8', mode = 'r') as f:
        raw_text = f.read()
    if len(raw_text) < 1000000:  # SpaCy will throw a memory error if a text is more than 1,000,000 characters
        lemmas = get_noun_and_verb_lemmas(raw_text)
        gibbon_lemmas[chapter_name] = lemmas
    else:
        print(f"Long chapter: {chapter_name}")
        lemmas = []
        text_lines = raw_text.split('\n')
        for text_line in text_lines:
            line_lemmas = get_noun_and_verb_lemmas(text_line)
            for line_lemma in line_lemmas:
                lemmas.append(line_lemma)
        gibbon_lemmas[chapter_name] = lemmas

# %%
# Sanity check
print(gibbon_lemmas.keys())
# Out:
# dict_keys(['chap01', 'chap02', 'chap03', 'chap04', 'chap05', 'chap06', 'chap07', 'chap08', 'chap09', 'chap10', 'chap11', 'chap12', 'chap13', 'chap14', 'chap15', 'chap16', 'chap17', 'chap18', 'chap19', 'chap20', 'chap21', 'chap22', 'chap23', 'chap24', 'chap25', 'chap26', 'chap27', 'chap28', 'chap29', 'chap30', 'chap31', 'chap32', 'chap33', 'chap34', 'chap35', 'chap36', 'chap37', 'chap38', 'chap39', 'chap40', 'chap41', 'chap42', 'chap43', 'chap44', 'chap45', 'chap46', 'chap47', 'chap48', 'chap49', 'chap50', 'chap51', 'chap52', 'chap53', 'chap54', 'chap55', 'chap56', 'chap57', 'chap58', 'chap59', 'chap60', 'chap61', 'chap62', 'chap63', 'chap64', 'chap65', 'chap66', 'chap67', 'chap68', 'chap69', 'chap70', 'chap71'])

# %%
# this code will save the data as a json file
file_name = 'gibbon_lemmas.json'
with open(file_name, encoding='utf-8', mode='w') as f:
    json.dump(gibbon_lemmas, f)

# %%
with open('gibbon_lemmas.json', encoding='utf8', mode='r') as f:
    gibbon_lemmas = json.load(f)

# %% [markdown]
# ## Find the most important words by chapter in Gibbon
# For this part we are going to use a library called [scikit-learn](https://scikit-learn.org/stable/). This library is primarily for machine learning, but many of its features are useful for DH work.
# Advanced Reading: https://towardsdatascience.com/tf-idf-explained-and-python-sklearn-implementation-b020c5e83275

# %%
# The tool I will use here requires a string as input rather than a list, so I convert my docs from lists to strings
gibbon_chap_strings = []
gibbon_chap_names = []
for key, value in gibbon_lemmas.items():
    gibbon_chap_names.append(key)  
    chap_string = ' '.join(value)
    gibbon_chap_strings.append(chap_string)

# %%
# transform corpus into a matrix of word counts
vectorizer = TfidfVectorizer(max_df=.65, min_df=1, stop_words=None, 
                             use_idf= True, norm=None)
transformed_chaps = vectorizer.fit_transform(gibbon_chap_strings)
transformed_chaps_as_array = transformed_chaps.toarray()

# %%
gibbon_key_vocab_by_chap = {}
for chap, chap_name in zip(transformed_chaps_as_array, gibbon_chap_names):
    tf_idf_tuples = list(zip(vectorizer.get_feature_names_out(), chap))
    sorted_tf_idf_tuples = sorted(tf_idf_tuples, key= lambda x: x[1], reverse=True)
    k = chap_name
    v = sorted_tf_idf_tuples[:10]  # only getting the top ten
    gibbon_key_vocab_by_chap[k] = v

# %%
for k, v in gibbon_key_vocab_by_chap.items():
    result = k + ' => ' + v[0][0] + ', ' + v[1][0] + ', ' + v[2][0] + ', ' + v[3][0] + ', ' + v[4][0]
    print(result)
# Out:
# chap01 => barbarian, comprehend, auxiliary, pilum, cohort
# chap02 => aqueduct, god, provincial, splendour, edifice
# chap03 => commonwealth, constitution, consul, adoption, thing
# chap04 => gladiator, amphitheatre, beast, amusement, assassin
# chap05 => have, competitor, 13th, superiority, 28th
# chap06 => excise, mutiny, legacy, tax, taxation
# chap07 => barbarian, election, game, gladiator, other
# chap08 => satrap, tract, article, universe, wrest
# chap09 => barbarian, warrior, reindeer, iron, liquor
# chap10 => barbarian, goth, censor, devastation, invader
# chap11 => barbarian, queen, goth, coin, supresse
# chap12 => barbarian, interregnum, election, amphitheatre, consul
# chap13 => barbarian, narse, tiridate, colleague, abdication
# chap14 => constantine, superiority, barbarian, acquaint, levy
# chap15 => doctrine, apostle, presbyter, daemon, immortality
# chap16 => persecution, edict, martyr, martyrdom, sect
# chap17 => praefect, capitation, consul, indiction, barbarian
# chap18 => plain, barbarian, nephew, negotiation, sister
# chap19 => barbarian, obelisk, eunuch, garrison, praefect
# chap20 => conversion, cross, baptism, labarum, piety
# chap21 => primate, logo, episcopal, controversy, catholic
# chap22 => tribunal, barbarian, consul, praefect, oblige
# chap23 => god, deity, paganism, toleration, rebuild
# chap24 => barbarian, sophist, elephant, satrap, bridge
# chap25 => valen, barbarian, magic, pirate, infantry
# chap26 => barbarian, goth, valen, tartar, plain
# chap27 => archbishop, barbarian, episcopal, armour, arbogaste
# chap28 => martyr, god, paganism, relic, idol
# chap29 => praefect, barbarian, stilicho, count, favourite
# chap30 => barbarian, poet, goth, vandal, entrenchment
# chap31 => barbarian, goth, usurper, vandal, famine
# chap32 => archbishop, eunuch, barbarian, empress, sister
# chap33 => vandal, carthage, barbarian, donatist, moor
# chap34 => barbarian, embassy, deserter, table, interpreter
# chap35 => barbarian, patrician, waggon, plain, chalon
# chap36 => vandal, barbarian, carthage, praefect, confederate
# chap37 => monk, monastery, barbarian, catholic, persecution
# chap38 => barbarian, clovis, provincial, diocese, poitier
# chap39 => favor, honor, consul, clamor, neighborhood
# chap40 => blue, silk, green, cupola, worm
# chap41 => vandal, carthage, vitige, goth, ditch
# chap42 => chosroe, silk, gubaze, skin, khan
# chap43 => comet, honor, narse, goth, valor
# chap44 => civilian, jurisprudence, praetor, honor, decemvir
# chap45 => exarch, honor, chagan, duke, pope
# chap46 => chosroe, chagan, satrap, elephant, centurion
# chap47 => patriarch, synod, honor, heresy, monk
# chap48 => patriarch, dynasty, surname, patrician, empress
# chap49 => pope, exarch, donation, duke, pontiff
# chap50 => prophet, apostle, camel, caliph, angel
# chap51 => caliph, prophet, mosch, abstinence, stipend
# chap52 => caliph, saracen, prophet, commander, mosch
# chap53 => tactic, theme, caliph, silk, tier
# chap54 => doctrine, reformer, sect, heretic, congregation
# chap55 => canoe, missionary, conversion, baptism, emigration
# chap56 => duke, galley, pope, saracen, count
# chap57 => sultan, caliph, dynasty, emir, pilgrim
# chap58 => crusader, knight, pilgrim, count, crusade
# chap59 => sultan, crusade, pilgrim, knight, caliph
# chap60 => baron, pilgrim, crusader, marquis, knight
# chap61 => baron, crusade, knight, marshal, despot
# chap62 => patriarch, duke, pope, prelate, constable
# chap63 => cell, galley, patriarch, elder, regent
# chap64 => sultan, khan, emir, tartar, knight
# chap65 => sultan, cage, emir, vizier, iron
# chap66 => pope, patriarch, synod, cardinal, pontiff
# chap67 => sultan, despot, legate, crusade, cardinal
# chap68 => sultan, cannon, vizier, bullet, harbour
# chap69 => pope, cardinal, election, conclave, metropolis
# chap70 => pope, cardinal, baron, bell, tribune
# chap71 => arch, coliseum, amphitheatre, marble, column

# %%
# explore vocabulary
gibbon_key_vocab_by_chap['chap16']  # <-- you can investigate other chapters
# Out:
# [('persecution', 146.20466756960525),
#  ('edict', 102.9002540472015),
#  ('martyr', 99.60116189189809),
#  ('martyrdom', 63.76593707003259),
#  ('sect', 59.510390209596395),
#  ('publish', 54.38859338326309),
#  ('conviction', 47.67396668556541),
#  ('severity', 45.570112506617804),
#  ('proconsul', 45.073393141972936),
#  ('suffering', 42.32867951399864)]

# %% [markdown]
# ## Conditional frequency distribution in Gibbon
#
# ### Natural Language Toolkit
# The **Natural Language Toolkit** (NLTK) is a library used for natural language processing (NLP). If you want to learn more, I highly recommend working through the [NLTK Book](https://www.nltk.org/book/). This resource is a great introduction to NLP specifically and Python more generally.
#
# A **conditional frequency distribution** (cfd) is a collection of word counts for a given condition, i.e. category. Here the category is separate chapters in Gibbon. We can chart what used are used most frequently by chapter. This will tell us something about the nature of each chapter.

# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#                                               0.0/1.5 MB ? eta -:--:--
#                                               0.0/1.5 MB ? eta -:--:--
#                                               0.0/1.5 MB 445.2 kB/s eta 0:00:04
#      -----                                    0.2/1.5 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------  1.5/1.5 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: click in c:\users\enhwi\miniconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\enhwi\miniconda3\lib\site-packages (from nltk) (1.3.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2023.10.3-cp311-cp311-win_amd64.whl (269 kB)
#                                               0.0/269.6 kB ? eta -:--:--
#      ------------------------------------- 269.6/269.6 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\enhwi\miniconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\enhwi\miniconda3\lib\site-packages (from click->nltk) (0.4.6)
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.8.1 regex-2023.10.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlibNote: you may need to restart the kernel to use updated packages.
#
#   Downloading matplotlib-3.8.0-cp311-cp311-win_amd64.whl (7.6 MB)
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.1/7.6 MB 1.1 MB/s eta 0:00:07
#      ---                                      0.8/7.6 MB 6.8 MB/s eta 0:00:02
#      ---------------                          3.0/7.6 MB 20.9 MB/s eta 0:00:01
#      ---------------------------              5.3/7.6 MB 26.2 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 32.5 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 28.7 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.1.1-cp311-cp311-win_amd64.whl (480 kB)
#                                               0.0/480.5 kB ? eta -:--:--
#      ------------------------------------- 480.5/480.5 kB 31.4 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.43.1-cp311-cp311-win_amd64.whl (2.1 MB)
#                                               0.0/2.1 MB ? eta -:--:--
#      ---------------------------------------  2.1/2.1 MB 45.3 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 45.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#                                               0.0/56.1 kB ? eta -:--:--
#      ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\enhwi\miniconda3\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\enhwi\miniconda3\lib\site-packages (from matplotlib) (23.0)
# Collecting pillow>=6.2.0 (from matplotlib)
#   Downloading Pillow-10.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
#                                               0.0/2.6 MB ? eta -:--:--
#      ---------------------------------------  2.6/2.6 MB 55.1 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 41.9 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#                                               0.0/103.1 kB ? eta -:--:--
#      ---------------------------------------- 103.1/103.1 kB ? eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\enhwi\miniconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\enhwi\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.43.1 kiwisolver-1.4.5 matplotlib-3.8.0 pillow-10.1.0 pyparsing-3.1.1

# %%
import nltk
import matplotlib.pyplot as plt

# %%
# conditional frequency distribution
cfd = nltk.ConditionalFreqDist(
    (target, chap_name)
    for chap_name in gibbon_lemmas.keys()
    for lemma in gibbon_lemmas[chap_name]
    for target in ['doctrine', 'apostle', 'presbyter', 'daemon', 'immortality']  # <-- instert token(s) to explore (lowercase)
    if lemma.lower().startswith(target)
)
# display plot
plt.figure(figsize=(20, 8))  # this expands the plot to make it more readable
cfd.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### Activity
# Based on the key vocabulary by chapter above, explore the use of different terms in the conditional frequency distribution.
# * What questions about the text does this raise for you?
# * What hypotheses about the text can you form?
